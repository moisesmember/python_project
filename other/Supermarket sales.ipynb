# %%
import pandas as pd
from prettytable import PrettyTable

# %%
sales = pd.read_csv('/home/hadoop/dataset/supermarket_sales - Sheet1.csv');

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
filter_to_data = sales[(sales['date'] >= '1/1/2019') & (sales['date'] <= '1/31/2019')
filter_to_data
# Out:
#   File "<ipython-input-78-68d0034380d5>", line 2
#     #filter_to_data
#                    ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# <h3>Verificação de Cálculo do valor</h3>

# %%
sales.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total      Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715  1/5/2019  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1

# %%
print('Preço unitário: ', sales['Unit price'].head(1))
print('------------------------------------------------')
print('Quantidade vendido: ',sales['Quantity'].head(1))
print('------------------------------------------------')

total = sales['Unit price'].head(1) * sales['Quantity'].head(1)
total_tax = ( total + sales['Tax 5%'].head(1))
# total_tax = ( total + (total*sales['Tax 5%'].head(1)) )
# print((total*0.05)) # cálculo da taxa
print('Preço total: ', total)
print('------------------------------------------------')
print('Preço total com a taxa: ', total_tax)
# Out:
# Preço unitário:  0    74.69
# Name: Unit price, dtype: float64
# ------------------------------------------------
# Quantidade vendido:  0    7
# Name: Quantity, dtype: int64
# ------------------------------------------------
# Preço total:  0    522.83
# dtype: float64
# ------------------------------------------------
# Preço total com a taxa:  0    548.9715
# dtype: float64

# %% [markdown]
# <h3>Detalhes financeiros</h3>

# %% [markdown]
# <h4>Faturamento por Categoria (Branch)</h4>

# %%
agrupar_branch = sales.groupby(['Branch','City']).agg({'Total':sum})
lucro_categoria = agrupar_branch.apply(lambda x: x.sort_values(ascending=False).head(4))
lucro_categoria
# Out:
#                         Total
# Branch City
# C      Naypyitaw  110568.7065
# A      Yangon     106200.3705
# B      Mandalay   106197.6720

# %% [markdown]
# <h4>Quantidade de Vendas por Categoria (Branch)</h4>

# %%
qtde_venda = sales.groupby('Branch')['Branch'].count().sort_values(ascending=False)
qtde_venda
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %% [markdown]
# <h4>Quantidade de Vendas por Produto</h4>

# %%
# Lucro de Produtos por Categoria
agrupar_product = sales.groupby(['Product line','Branch','City']).agg({'Total':sum})
lucro_produto_categoria = agrupar_product.apply(lambda x: x.sort_values(ascending=False).head(10))
lucro_produto_categoria
# Out:
#                                               Total
# Product line           Branch City
# Food and beverages     C      Naypyitaw  23766.8550
# Home and lifestyle     A      Yangon     22417.1955
# Fashion accessories    C      Naypyitaw  21560.0700
# Sports and travel      B      Mandalay   19988.1990
# Health and beauty      B      Mandalay   19980.6600
# Sports and travel      A      Yangon     19372.6995
# Electronic accessories C      Naypyitaw  18968.9745
#                        A      Yangon     18317.1135
# Home and lifestyle     B      Mandalay   17549.1645
# Food and beverages     A      Yangon     17163.1005

# %%
# Lucro por Produtos
agrupar_product = sales.groupby(['Product line']).agg({'Total':sum})
lucro_produto = agrupar_product.apply(lambda x: x.sort_values(ascending=False).head(10))
lucro_produto
# Out:
#                              Total
# Product line
# Food and beverages      56144.8440
# Sports and travel       55122.8265
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Home and lifestyle      53861.9130
# Health and beauty       49193.7390

# %%
# Quantidade de Venda por Produto
qtde_venda_produto = sales.groupby('Product line')['Product line'].count().sort_values(ascending=False)
# O valor retornado é uma pandas.Series
# qtde_venda_produto.index
# qtde_venda_produto.values
# qtde_venda_produto.size

# Conversão de pandas.Series para Dataframe
qtde_venda_produtos = pd.DataFrame({'product':qtde_venda_produto.index, 'qtde':qtde_venda_produto.values})
qtde_venda_produtos
# Out:
#                   product  qtde
# 0     Fashion accessories   178
# 1      Food and beverages   174
# 2  Electronic accessories   170
# 3       Sports and travel   166
# 4      Home and lifestyle   160
# 5       Health and beauty   152

# %%
https://medium.com/brdata/correla%C3%A7%C3%A3o-direto-ao-ponto-9ec1d48735fb
